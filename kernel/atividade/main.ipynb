# %%
from tensorflow.keras import models, layers, activations, initializers, optimizers, losses, metrics,utils

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), # 28x28x1
    layers.Conv2D(10, kernel_size=(3,3), strides=(1,1), padding='same'), # 10 @ 28x28
    layers.Flatten(), # 7840
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()), # 64
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal()) # 24
])

# %%
lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

# %%
path = './Data'
batch_size = 25

train = utils.image_dataset_from_directory(
    directory=path + '/Train',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path + '/Test',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)
# Out:
# Found 50000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), 
    
    layers.Resizing(28,28),
    layers.Rescaling(1./255),
    # layers.RandomRotation((-0.2, 0.2)),

    layers.Conv2D(32, (3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),

    layers.Conv2D(64, (3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
    
    layers.Conv2D(128,(3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),

   
    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal())
])

from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 2
epochs = 200
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        )
    ]
)
# Out:
# <>:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:12: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:15: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:12: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:15: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\disrct\AppData\Local\Temp\ipykernel_11144\3445193142.py:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
# C:\Users\disrct\AppData\Local\Temp\ipykernel_11144\3445193142.py:12: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
# C:\Users\disrct\AppData\Local\Temp\ipykernel_11144\3445193142.py:15: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       1 model = models.Sequential([
#       2     layers.Input(shape=(28,28,3)),
#       3
#       4     layers.Resizing(28,28),
#       5     layers.Rescaling(1./255),
#       6     # layers.RandomRotation((-0.2, 0.2)),
#       7
#       8     layers.Conv2D(32, (3,3),padding='same',activation='relu'),
# ----> 9     layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
#      10
#      11     layers.Conv2D(64, (3,3),padding='same',activation='relu'),
#      12     layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
#      13
#      14     layers.Conv2D(128,(3,3),padding='same',activation='relu'),
#      15     layers.MaxPooling2D(32(2,2), strides=(1,1), padding='same'),
#      16
#      17
#      18     layers.GlobalAveragePooling2D(),
#      19
#      20     layers.Dense(128, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
#      21     layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal())
#      22 ])
#      24 from tensorflow.keras import optimizers, losses, metrics
#      26 lr = 0.001
#
# TypeError: 'int' object is not callable
