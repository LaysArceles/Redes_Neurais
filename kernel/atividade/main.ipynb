# %%
from tensorflow.keras import models, layers, activations, initializers, optimizers, losses, metrics,utils

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), # 28x28x1
    layers.Conv2D(10, kernel_size=(3,3), strides=(1,1), padding='same'), # 10 @ 28x28
    layers.Flatten(), # 7840
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()), # 64
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal()) # 24
])

# %%
lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

# %%
path = './Data'
batch_size = 25

train = utils.image_dataset_from_directory(
    directory=path + '/Train',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path + '/Test',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)
# Out:
# Found 50000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), 
    
    layers.Resizing(28,28),
    layers.Rescaling(1./255),
    # layers.RandomRotation((-0.2, 0.2)),

    layers.Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.MaxPooling2D(pool_size=(3,3), strides=1, padding='same'),
    layers.Conv2D(16, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.Conv2D(16, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='same'),

    layers.Flatten(),

    layers.Dense(32, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dropout(0.2),
    layers.Dense(32, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),

    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal())
])

from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 2
epochs = 200
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        )
    ]
)
# Out:
# Epoch 1/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - loss: 1.6412 - sparse_categorical_accuracy: 0.4030 - val_loss: 1.2838 - val_sparse_categorical_accuracy: 0.5509
# Epoch 2/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 33s 17ms/step - loss: 1.2827 - sparse_categorical_accuracy: 0.5486 - val_loss: 1.1889 - val_sparse_categorical_accuracy: 0.5852
# Epoch 3/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 18ms/step - loss: 1.1616 - sparse_categorical_accuracy: 0.5941 - val_loss: 1.0628 - val_sparse_categorical_accuracy: 0.6336
# Epoch 4/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - loss: 1.1022 - sparse_categorical_accuracy: 0.6156 - val_loss: 1.0644 - val_sparse_categorical_accuracy: 0.6367
# Epoch 5/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 18ms/step - loss: 1.0616 - sparse_categorical_accuracy: 0.6277 - val_loss: 1.0584 - val_sparse_categorical_accuracy: 0.6336
# Epoch 6/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - loss: 1.0273 - sparse_categorical_accuracy: 0.6430 - val_loss: 1.0397 - val_sparse_categorical_accuracy: 0.6392
# Epoch 7/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - loss: 0.9980 - sparse_categorical_accuracy: 0.6520 - val_loss: 1.0434 - val_sparse_categorical_accuracy: 0.6384
# Epoch 8/200
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 33s 17ms/step - loss: 0.9689 - sparse_categorical_accuracy: 0.6635 - val_loss: 1.0557 - val_sparse_categorical_accuracy: 0.6345
# Epoch 8: early stopping
