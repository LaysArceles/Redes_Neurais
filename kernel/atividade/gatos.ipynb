# %%
from tensorflow.keras import models, layers, activations, initializers, optimizers, losses, metrics,utils

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), # 28x28x1
    layers.Conv2D(10, kernel_size=(3,3), strides=(1,1), padding='same'), # 10 @ 28x28
    layers.Flatten(), # 7840
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()), # 64
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal()) # 24
])

# %%
lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

# %%
path = './Data'
batch_size = 128

train = utils.image_dataset_from_directory(
    directory=path,
    shuffle = True,
    seed = 1,
    subset='training',
    validation_split=0.1,
    image_size = (28,28),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path,
    shuffle = True,
    seed = 1,
    subset='validation',
    validation_split=0.1,
    image_size = (28,28),
    batch_size = batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1800 files for training.
# Found 2000 files belonging to 2 classes.
# Using 200 files for validation.

# %%
model = models.Sequential([
    layers.Input(shape=(28,28,3)), 
    
    layers.Resizing(28,28),
    layers.Rescaling(1./255),
    # layers.RandomRotation((-0.2, 0.2)),

    layers.Conv2D(32, (3,3),padding='same',activation='relu'),
    layers.Conv2D(32, (3,3),padding='same',activation='relu'),
    layers.MaxPooling2D((2,2), strides=(1,1), padding='same'),

    layers.Conv2D(64, (3,3),padding='same',activation='relu'),
    layers.Conv2D(64, (3,3),padding='same',activation='relu'),
    layers.MaxPooling2D((2,2), strides=(1,1), padding='same'),
    
    layers.Conv2D(128,(3,3),padding='same',activation='relu'),
    layers.Conv2D(128,(3,3),padding='same',activation='relu'),
    layers.MaxPooling2D((2,2), strides=(1,1), padding='same'),

   
    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal())
])

from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 5
epochs = 100
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        )
    ]
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.7617 - sparse_categorical_accuracy: 0.4667 - val_loss: 0.6963 - val_sparse_categorical_accuracy: 0.5450
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 923ms/step - loss: 0.7549 - sparse_categorical_accuracy: 0.4939 - val_loss: 0.6987 - val_sparse_categorical_accuracy: 0.5450
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 903ms/step - loss: 0.7073 - sparse_categorical_accuracy: 0.5106 - val_loss: 0.6969 - val_sparse_categorical_accuracy: 0.4550
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 976ms/step - loss: 0.6966 - sparse_categorical_accuracy: 0.5094 - val_loss: 0.7084 - val_sparse_categorical_accuracy: 0.4550
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 941ms/step - loss: 0.7129 - sparse_categorical_accuracy: 0.5044 - val_loss: 0.6952 - val_sparse_categorical_accuracy: 0.5450
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 935ms/step - loss: 0.7041 - sparse_categorical_accuracy: 0.5006 - val_loss: 0.6885 - val_sparse_categorical_accuracy: 0.5450
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 861ms/step - loss: 0.7027 - sparse_categorical_accuracy: 0.4972 - val_loss: 0.6905 - val_sparse_categorical_accuracy: 0.5450
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 489ms/step - loss: 0.6962 - sparse_categorical_accuracy: 0.5044 - val_loss: 0.6878 - val_sparse_categorical_accuracy: 0.5450
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 549ms/step - loss: 0.6994 - sparse_categorical_accuracy: 0.4889 - val_loss: 0.6883 - val_sparse_categorical_accuracy: 0.5450
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 487ms/step - loss: 0.6958 - sparse_categorical_accuracy: 0.5100 - val_loss: 0.6980 - val_sparse_categorical_accuracy: 0.4550
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 493ms/step - loss: 0.6977 - sparse_categorical_accuracy: 0.4839 - val_loss: 0.6899 - val_sparse_categorical_accuracy: 0.5450
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 521ms/step - loss: 0.6945 - sparse_categorical_accuracy: 0.4772 - val_loss: 0.6911 - val_sparse_categorical_accuracy: 0.5450
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 888ms/step - loss: 0.6954 - sparse_categorical_accuracy: 0.4806 - val_loss: 0.7396 - val_sparse_categorical_accuracy: 0.4550
# Epoch 13: early stopping
